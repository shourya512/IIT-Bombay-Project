# %%
from ast import increment_lineno
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import style

# %%
#read csv file using panda

data = pd.read_csv('/content/country_wise_latest.csv')

data
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
country== data['Country/Region']
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 182    True
# 183    True
# 184    True
# 185    True
# 186    True
# Name: Country/Region, Length: 187, dtype: bool

# %%
deaths = data['Deaths']

# %%
positions = np.arange(len(country))

# %%
fir = plt.figure(figsize=(50,20))
plt.bar(country,deaths)
plt.xlabel('country')
plt.ylabel('deaths')
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fir = plt.figure(figsize=(10,90))
plt.barh(country,deaths)
plt.xlabel('country')
plt.ylabel('deaths')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-53174f4a1e60> in <cell line: 1>()
# ----> 1 fir = plt.figure(figsize=(10,90))
#       2 plt.barh(country,deaths)
#       3 plt.xlabel('country')
#       4 plt.ylabel('deaths')
#       5 plt.legend()
#
# NameError: name 'plt' is not defined
